# %% [markdown]
# # Linear dataset with both 4 neurons in 2 hidden layers

# %%
import actfcn
import optimizer
import nn
import utils
import numpy as np
import matplotlib.pyplot as plt

if __name__ == "__main__":
    np.random.seed(10)
    x, y = utils.generate_linear(100)
    
    dims = (4, 4)
    bias = True
    act = actfcn.Sigmoid()
    opt = optimizer.SGD(0.01)
    
    nn = nn.NN(dims, bias, act, opt)
    loss = utils.MSE()
    losses = []
    accuracies = []
    y_pred = []
    
    epochs = int(1000)
    for epoch in range(epochs):
        y_pred = nn.forward(x)
        loss_value = loss.forward(y, y_pred)
        losses.append(loss_value)
        accuracy_value = utils.accuracy(y, y_pred)
        accuracies.append(accuracy_value)

        dy = loss.backward(y, y_pred)
        nn.backward(dy)

        if epoch % (epochs / 10) == 0:
            print(f"epoch: {epoch}, loss: {loss_value}, accuracy: {accuracy_value}")

    y_pred = np.around(y_pred)
    utils.show_result(x, y, y_pred)
    plt.xlabel('Epochs')
    plt.ylabel('Losses')
    plt.plot(losses)
    plt.show()
    plt.xlabel('Epochs')
    plt.ylabel('Accuracies')
    plt.plot(accuracies)
    plt.plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 17
#      14 act = actfcn.Sigmoid()
#      15 opt = optimizer.SGD(0.01)
# ---> 17 nn = nn.NN(dims, bias, act, opt)
#      18 loss = utils.MSE()
#      19 losses = []
#
# File ~/nycu-deep-learning-2023-spring/lab1/src/nn.py:55, in NN.__init__(self, dims, have_bias, act_fcn, optimizer, optimizer_parameter)
#      46 def __init__(
#      47     self,
#      48     dims,
#    (...)
#      52     optimizer_parameter=optimizer.Optimizer
#      53 ):
#      54     self.layers = (
# ---> 55         Layer(2, dims[0], have_bias, act_fcn, optimizer, optimizer_parameter),
#      56         Layer(dims[0], dims[1], have_bias, act_fcn, optimizer, optimizer_parameter),
#      57         Layer(dims[1], 1, have_bias, act_fcn, optimizer, optimizer_parameter),
#      58     )
#
# File ~/nycu-deep-learning-2023-spring/lab1/src/nn.py:20, in Layer.__init__(self, input_dim, output_dim, have_bias, act_fcn, optimizer, optimizer_parameter)
#      18 self.output_dim = output_dim
#      19 self.have_bias = have_bias
# ---> 20 self.act_fcn = act_fcn()
#      21 self.optimizer = optimizer(*optimizer_parameter.get_param)
#      23 self.w = np.random.randn(self.input_dim, self.output_dim)
#
# TypeError: 'Sigmoid' object is not callable

# %% [markdown]
# # Linear dataset with both 2 neurons in 2 hidden layers

# %%
import actfcn
import optimizer
import nn
import utils
import numpy as np
import matplotlib.pyplot as plt

if __name__ == "__main__":
    np.random.seed(10)
    x, y = utils.generate_linear(100)
    
    dims = (2, 2)
    bias = True
    act = actfcn.Sigmoid()
    opt = optimizer.SGD(0.01)
    
    nn = nn.NN(dims, bias, act, opt)
    loss = utils.MSE()
    losses = []
    accuracies = []
    y_pred = []
    
    epochs = int(1000)
    for epoch in range(epochs):
        y_pred = nn.forward(x)
        loss_value = loss.forward(y, y_pred)
        losses.append(loss_value)
        accuracy_value = utils.accuracy(y, y_pred)
        accuracies.append(accuracy_value)

        dy = loss.backward(y, y_pred)
        nn.backward(dy)

        if epoch % (epochs / 10) == 0:
            print(f"epoch: {epoch}, loss: {loss_value}, accuracy: {accuracy_value}")

    y_pred = np.around(y_pred)
    utils.show_result(x, y, y_pred)
    plt.xlabel('Epochs')
    plt.ylabel('Losses')
    plt.plot(losses)
    plt.show()
    plt.xlabel('Epochs')
    plt.ylabel('Accuracies')
    plt.plot(accuracies)
    plt.plot()
# Out:
# epoch: 0, loss: 0.249780302760514, accuracy: 0.55
# epoch: 100, loss: 0.24281226741239756, accuracy: 0.55
# epoch: 200, loss: 0.22999274169184397, accuracy: 0.56
# epoch: 300, loss: 0.15710375483358566, accuracy: 0.93
# epoch: 400, loss: 0.06662070006820899, accuracy: 0.99
# epoch: 500, loss: 0.039471525112686076, accuracy: 1.0
# epoch: 600, loss: 0.029136535206432446, accuracy: 1.0
# epoch: 700, loss: 0.023678046268725928, accuracy: 1.0
# epoch: 800, loss: 0.020208025459975798, accuracy: 1.0
# epoch: 900, loss: 0.0177524952462032, accuracy: 1.0

# %% [markdown]
# # Linear dataset with both 32 neurons in 2 hidden layers

# %%
import actfcn
import optimizer
import nn
import utils
import numpy as np
import matplotlib.pyplot as plt

if __name__ == "__main__":
    np.random.seed(10)
    x, y = utils.generate_linear(100)
    
    dims = (8, 8)
    bias = True
    act = actfcn.Sigmoid()
    opt = optimizer.SGD(0.01)
    
    nn = nn.NN(dims, bias, act, opt)
    loss = utils.MSE()
    losses = []
    accuracies = []
    y_pred = []
    
    epochs = int(1000)
    for epoch in range(epochs):
        y_pred = nn.forward(x)
        loss_value = loss.forward(y, y_pred)
        losses.append(loss_value)
        accuracy_value = utils.accuracy(y, y_pred)
        accuracies.append(accuracy_value)

        dy = loss.backward(y, y_pred)
        nn.backward(dy)

        if epoch % (epochs / 10) == 0:
            print(f"epoch: {epoch}, loss: {loss_value}, accuracy: {accuracy_value}")

    y_pred = np.around(y_pred)
    utils.show_result(x, y, y_pred)
    plt.xlabel('Epochs')
    plt.ylabel('Losses')
    plt.plot(losses)
    plt.show()
    plt.xlabel('Epochs')
    plt.ylabel('Accuracies')
    plt.plot(accuracies)
    plt.plot()
# Out:
# epoch: 0, loss: 0.3600339309466477, accuracy: 0.45
# epoch: 100, loss: 0.16689471384166887, accuracy: 0.88
# epoch: 200, loss: 0.06659676320487211, accuracy: 1.0
# epoch: 300, loss: 0.038835266643326496, accuracy: 1.0
# epoch: 400, loss: 0.028640201672198263, accuracy: 1.0
# epoch: 500, loss: 0.023297867933457433, accuracy: 1.0
# epoch: 600, loss: 0.019897951083810796, accuracy: 1.0
# epoch: 700, loss: 0.017481221309720102, accuracy: 1.0
# epoch: 800, loss: 0.015642498191578442, accuracy: 1.0
# epoch: 900, loss: 0.014179575975289833, accuracy: 1.0

# %% [markdown]
# # XOR dataset with both 4 neurons in 2 hidden layers

# %%
import actfcn
import optimizer
import nn
import utils
import numpy as np
import matplotlib.pyplot as plt

if __name__ == "__main__":
    np.random.seed(10)
    x, y = utils.generate_XOR_easy()
    
    dims = (4, 4)
    bias = True
    act = actfcn.Sigmoid()
    opt = optimizer.SGD(0.01)
    
    nn = nn.NN(dims, bias, act, opt)
    loss = utils.MSE()
    losses = []
    accuracies = []
    y_pred = []
    
    epochs = int(10000)
    for epoch in range(epochs):
        y_pred = nn.forward(x)
        loss_value = loss.forward(y, y_pred)
        losses.append(loss_value)
        accuracy_value = utils.accuracy(y, y_pred)
        accuracies.append(accuracy_value)

        dy = loss.backward(y, y_pred)
        nn.backward(dy)

        if epoch % (epochs / 10) == 0:
            print(f"epoch: {epoch}, loss: {loss_value}, accuracy: {accuracy_value}")

    y_pred = np.around(y_pred)
    utils.show_result(x, y, y_pred)
    plt.xlabel('Epochs')
    plt.ylabel('Losses')
    plt.plot(losses)
    plt.show()
    plt.xlabel('Epochs')
    plt.ylabel('Accuracies')
    plt.plot(accuracies)
    plt.plot()
# Out:
# epoch: 0, loss: 0.3207647588892037, accuracy: 0.47619047619047616
# epoch: 1000, loss: 0.2487133667562864, accuracy: 0.5238095238095238
# epoch: 2000, loss: 0.2475132921125923, accuracy: 0.5238095238095238
# epoch: 3000, loss: 0.24426297972530572, accuracy: 0.6190476190476191
# epoch: 4000, loss: 0.2308542521833423, accuracy: 0.6666666666666666
# epoch: 5000, loss: 0.16375823104729859, accuracy: 0.8095238095238095
# epoch: 6000, loss: 0.0834434833592583, accuracy: 0.9047619047619048
# epoch: 7000, loss: 0.051018131674399045, accuracy: 0.9047619047619048
# epoch: 8000, loss: 0.031055700737388593, accuracy: 1.0
# epoch: 9000, loss: 0.018200919185683957, accuracy: 1.0

# %% [markdown]
# # XOR dataset with `lr = 0.001`

# %%
import actfcn
import optimizer
import nn
import utils
import numpy as np
import matplotlib.pyplot as plt

if __name__ == "__main__":
    np.random.seed(10)
    x, y = utils.generate_XOR_easy()
    
    dims = (4, 4)
    bias = True
    act = actfcn.Sigmoid()
    opt = optimizer.SGD(0.01)
    
    nn = nn.NN(dims, bias, act, opt)
    loss = utils.MSE()
    losses = []
    accuracies = []
    y_pred = []
    
    epochs = int(10000)
    for epoch in range(epochs):
        y_pred = nn.forward(x)
        loss_value = loss.forward(y, y_pred)
        losses.append(loss_value)
        accuracy_value = utils.accuracy(y, y_pred)
        accuracies.append(accuracy_value)

        dy = loss.backward(y, y_pred)
        nn.backward(dy)

        if epoch % (epochs / 10) == 0:
            print(f"epoch: {epoch}, loss: {loss_value}, accuracy: {accuracy_value}")

    y_pred = np.around(y_pred)
    utils.show_result(x, y, y_pred)
    plt.xlabel('Epochs')
    plt.ylabel('Losses')
    plt.plot(losses)
    plt.show()
    plt.xlabel('Epochs')
    plt.ylabel('Accuracies')
    plt.plot(accuracies)
    plt.plot()
# Out:
# epoch: 0, loss: 0.3207647588892037, accuracy: 0.47619047619047616
# epoch: 10000, loss: 0.2487127880484653, accuracy: 0.5238095238095238
# epoch: 20000, loss: 0.247511537034558, accuracy: 0.5238095238095238
# epoch: 30000, loss: 0.2442567226677756, accuracy: 0.6190476190476191
# epoch: 40000, loss: 0.2308211798232438, accuracy: 0.6666666666666666
# epoch: 50000, loss: 0.1636277170607126, accuracy: 0.8095238095238095
# epoch: 60000, loss: 0.08341276547283998, accuracy: 0.9047619047619048
# epoch: 70000, loss: 0.051017429462358266, accuracy: 0.9047619047619048
# epoch: 80000, loss: 0.03106216207940769, accuracy: 1.0
# epoch: 90000, loss: 0.018206591140286315, accuracy: 1.0

# %% [markdown]
# # XOR dataset with `lr = 0.1`

# %%
import actfcn
import optimizer
import nn
import utils
import numpy as np
import matplotlib.pyplot as plt

if __name__ == "__main__":
    np.random.seed(10)
    x, y = utils.generate_XOR_easy()
    
    dims = (4, 4)
    bias = True
    act = actfcn.Sigmoid()
    opt = optimizer.SGD(0.01)
    
    nn = nn.NN(dims, bias, act, opt)
    loss = utils.MSE()
    losses = []
    accuracies = []
    y_pred = []
    
    epochs = int(10000)
    for epoch in range(epochs):
        y_pred = nn.forward(x)
        loss_value = loss.forward(y, y_pred)
        losses.append(loss_value)
        accuracy_value = utils.accuracy(y, y_pred)
        accuracies.append(accuracy_value)

        dy = loss.backward(y, y_pred)
        nn.backward(dy)

        if epoch % (epochs / 10) == 0:
            print(f"epoch: {epoch}, loss: {loss_value}, accuracy: {accuracy_value}")

    y_pred = np.around(y_pred)
    utils.show_result(x, y, y_pred)
    plt.xlabel('Epochs')
    plt.ylabel('Losses')
    plt.plot(losses)
    plt.show()
    plt.xlabel('Epochs')
    plt.ylabel('Accuracies')
    plt.plot(accuracies)
    plt.plot()
# Out:
# epoch: 0, loss: 0.3207647588892037, accuracy: 0.47619047619047616
# epoch: 1000, loss: 0.011113840609292734, accuracy: 1.0
# epoch: 2000, loss: 0.0011764563678158778, accuracy: 1.0
# epoch: 3000, loss: 0.0005148860581559118, accuracy: 1.0
# epoch: 4000, loss: 0.00031355280719437854, accuracy: 1.0
# epoch: 5000, loss: 0.00022044756716753947, accuracy: 1.0
# epoch: 6000, loss: 0.00016788627881545194, accuracy: 1.0
# epoch: 7000, loss: 0.00013451469937034665, accuracy: 1.0
# epoch: 8000, loss: 0.00011161847254901886, accuracy: 1.0
# epoch: 9000, loss: 9.502059741953292e-05, accuracy: 1.0
